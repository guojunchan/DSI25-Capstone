# %%
# Basic Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
from scipy.stats import pearsonr, spearmanr

# %%
top = pd.read_csv('../data/top.csv')
upcoming = pd.read_csv('../data/final_comingsoon.csv')
movies = pd.read_csv('../data/movies.csv')
rating = pd.read_csv('../data/ratings.csv')

# %%
top.head()
# Out:
#    Unnamed: 0  id  id.1  id.1.1                     movie  year  time  rating  \
# 0           0   0     0       0                  Jai Bhim  2021   164     9.4
# 1           1   1     1       1  The Shawshank Redemption  1994   142     9.3
# 2           2   2     2       2             The Godfather  1972   175     9.2
# 3           3   3     3       3           Soorarai Pottru  2020   153     9.1
# 4           4   4     4       4           The Dark Knight  2008   152     9.0
#
#    score      votes   gross  \
# 0    NaN    156,320     NaN
# 1   80.0  2,504,049   28.34
# 2  100.0  1,726,068  134.97
# 3    NaN    104,396     NaN
# 4   84.0  2,453,580  534.86
#
#                                          description              director  \
# 0  When a tribal man is arrested for a case of al...         T.J. Gnanavel
# 1  Two imprisoned men bond over a number of years...        Frank Darabont
# 2  The Godfather follows Vito Corleone, Don of th...  Francis Ford Coppola
# 3  Nedumaaran Rajangam "Maara" sets out to make t...         Sudha Kongara
# 4  When the menace known as the Joker wreaks havo...     Christopher Nolan
#
#                                                 star  \
# 0  'Suriya' 'Lijo Mol Jose' 'Manikandan' 'Rajisha...
# 1  'Tim Robbins' 'Morgan Freeman' 'Bob Gunton' 'W...
# 2  'Marlon Brando' 'Al Pacino' 'James Caan' 'Dian...
# 3  'Suriya' 'Paresh Rawal' 'Aparna Balamurali' 'G...
# 4  'Christian Bale' 'Heath Ledger' 'Aaron Eckhart...
#
#                               genre
# 0          Crime, Drama
# 1                 Drama
# 2          Crime, Drama
# 3                 Drama
# 4  Action, Crime, Drama

# %%
top.columns = map(str.lower, top.columns)
top.columns = top.columns.str.replace(" ", "_")
#top.drop(['unnamed:_0'], axis=1, inplace=True)
top.rename(index={0: "movie", 1: "year", 2: "time", 3: "rating", 4: "metascore"})
top.rename(columns={'movie_name': 'movie', 'year_of_release': 'year', 'watch_time' : 'time', 'movie_rating' : 'rating', 'meatscore_of_movie' : 'score'}, inplace=True)
top.rename(columns={ top.columns[0]: "id" }, inplace = True)
top.head()
# Out:
#    id  id  id.1  id.1.1                     movie  year  time  rating  score  \
# 0   0   0     0       0                  Jai Bhim  2021   164     9.4    NaN
# 1   1   1     1       1  The Shawshank Redemption  1994   142     9.3   80.0
# 2   2   2     2       2             The Godfather  1972   175     9.2  100.0
# 3   3   3     3       3           Soorarai Pottru  2020   153     9.1    NaN
# 4   4   4     4       4           The Dark Knight  2008   152     9.0   84.0
#
#        votes   gross                                        description  \
# 0    156,320     NaN  When a tribal man is arrested for a case of al...
# 1  2,504,049   28.34  Two imprisoned men bond over a number of years...
# 2  1,726,068  134.97  The Godfather follows Vito Corleone, Don of th...
# 3    104,396     NaN  Nedumaaran Rajangam "Maara" sets out to make t...
# 4  2,453,580  534.86  When the menace known as the Joker wreaks havo...
#
#                director                                               star  \
# 0         T.J. Gnanavel  'Suriya' 'Lijo Mol Jose' 'Manikandan' 'Rajisha...
# 1        Frank Darabont  'Tim Robbins' 'Morgan Freeman' 'Bob Gunton' 'W...
# 2  Francis Ford Coppola  'Marlon Brando' 'Al Pacino' 'James Caan' 'Dian...
# 3         Sudha Kongara  'Suriya' 'Paresh Rawal' 'Aparna Balamurali' 'G...
# 4     Christopher Nolan  'Christian Bale' 'Heath Ledger' 'Aaron Eckhart...
#
#                               genre
# 0          Crime, Drama
# 1                 Drama
# 2          Crime, Drama
# 3                 Drama
# 4  Action, Crime, Drama

# %%
top.duplicated().sum()
# Out:
# 0

# %%
top.isnull().sum()
# Out:
# id               0
# id               0
# id.1             0
# id.1.1           0
# movie            0
# year             0
# time             0
# rating           0
# score          169
# votes            0
# gross          185
# description      0
# director         0
# star             0
# genre            0
# dtype: int64

# %%
top['year'] = top['year'].str.replace("(", "")
top['year'] = top['year'].str.replace(")", "")
#top['gross'] = top['gross'].str.replace("%", "")
#top['gross'] = top['gross'].str.replace("^", "")
#top['gross'] = top['gross'].str.replace("$", "")
#top['gross'] = top['gross'].str.replace("M", "")
#top['score'] = top['score'].str.replace("*", "")
#top['genre'] = top['genre'].str.replace("\n","")
#top['time'] = top['time'].str.replace("min","")
#pd.get_dummies(top['genre'])
top['star'] = top['star'].str.replace("[","")
top['star'] = top['star'].str.replace("]","")
top['star'] = top['star'].str.replace("''","")
top['star'] = top['star'].str.replace(",","")
# Out:
# <ipython-input-92-2fabb0a5e6ea>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   top['year'] = top['year'].str.replace("(", "")
# <ipython-input-92-2fabb0a5e6ea>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   top['year'] = top['year'].str.replace(")", "")
# <ipython-input-92-2fabb0a5e6ea>:11: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   top['star'] = top['star'].str.replace("[","")
# <ipython-input-92-2fabb0a5e6ea>:12: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   top['star'] = top['star'].str.replace("]","")

# %%
top.head()
# Out:
#    id  id  id.1  id.1.1                     movie  year  time  rating  score  \
# 0   0   0     0       0                  Jai Bhim  2021   164     9.4    NaN
# 1   1   1     1       1  The Shawshank Redemption  1994   142     9.3   80.0
# 2   2   2     2       2             The Godfather  1972   175     9.2  100.0
# 3   3   3     3       3           Soorarai Pottru  2020   153     9.1    NaN
# 4   4   4     4       4           The Dark Knight  2008   152     9.0   84.0
#
#        votes   gross                                        description  \
# 0    156,320     NaN  When a tribal man is arrested for a case of al...
# 1  2,504,049   28.34  Two imprisoned men bond over a number of years...
# 2  1,726,068  134.97  The Godfather follows Vito Corleone, Don of th...
# 3    104,396     NaN  Nedumaaran Rajangam "Maara" sets out to make t...
# 4  2,453,580  534.86  When the menace known as the Joker wreaks havo...
#
#                director                                               star  \
# 0         T.J. Gnanavel  'Suriya' 'Lijo Mol Jose' 'Manikandan' 'Rajisha...
# 1        Frank Darabont  'Tim Robbins' 'Morgan Freeman' 'Bob Gunton' 'W...
# 2  Francis Ford Coppola  'Marlon Brando' 'Al Pacino' 'James Caan' 'Dian...
# 3         Sudha Kongara  'Suriya' 'Paresh Rawal' 'Aparna Balamurali' 'G...
# 4     Christopher Nolan  'Christian Bale' 'Heath Ledger' 'Aaron Eckhart...
#
#                               genre
# 0          Crime, Drama
# 1                 Drama
# 2          Crime, Drama
# 3                 Drama
# 4  Action, Crime, Drama

# %%
top.sort_values(by=['gross'], ascending=False,inplace = True)

# %%
top.head(20)
# Out:
#       id   id  id.1  id.1.1                                          movie  \
# 618  618  618   618     618     Star Wars: Episode VII - The Force Awakens
# 66    66   66    66      66                              Avengers: Endgame
# 655  655  655   655     655                                         Avatar
# 67    67   67    67      67                         Avengers: Infinity War
# 680  680  680   680     680                                        Titanic
# 380  380  380   380     380                                   The Avengers
# 922  922  922   922     922                                  Incredibles 2
# 4      4    4     4       4                                The Dark Knight
# 611  611  611   611     611                                      Rogue One
# 70    70   70    70      70                          The Dark Knight Rises
# 712  712  712   712     712                     E.T. the Extra-Terrestrial
# 766  766  766   766     766                                    Toy Story 4
# 47    47   47    47      47                                  The Lion King
# 162  162  162   162     162                                    Toy Story 3
# 612  612  612   612     612                     Captain America: Civil War
# 278  278  278   278     278                                  Jurassic Park
# 920  920  920   920     920                 Guardians of the Galaxy Vol. 2
# 237  237  237   237     237   Harry Potter and the Deathly Hallows: Part 2
# 256  256  256   256     256                                   Finding Nemo
# 7      7    7     7       7  The Lord of the Rings: The Return of the King
#
#      year  time  rating  score      votes   gross  \
# 618  2015   138     7.8   80.0    892,221  936.66
# 66   2019   181     8.4   78.0    971,371  858.37
# 655  2009   162     7.8   83.0  1,167,413  760.51
# 67   2018   149     8.4   68.0    949,230  678.82
# 680  1997   194     7.8   75.0  1,107,940  659.33
# 380  2012   143     8.0   69.0  1,321,491  623.28
# 922  2018   118     7.6   80.0    273,769  608.58
# 4    2008   152     9.0   84.0  2,453,580  534.86
# 611  2016   133     7.8   65.0    587,711  532.18
# 70   2012   164     8.4   78.0  1,596,785  448.14
# 712  1982   115     7.8   91.0    390,986  435.11
# 766  2019   100     7.7   84.0    227,649  434.04
# 47   1994    88     8.5   88.0    995,397  422.78
# 162  2010   103     8.2   92.0    794,111  415.00
# 612  2016   147     7.8   75.0    721,718  408.08
# 278  1993   127     8.1   68.0    920,145  402.45
# 920  2017   136     7.6   67.0    622,579  389.81
# 237  2011   130     8.1   85.0    814,530  381.01
# 256  2003   100     8.1   90.0    993,521  380.84
# 7    2003   201     8.9   94.0  1,729,851  377.85
#
#                                            description  \
# 618  As a new threat to the galaxy rises, Rey, a de...
# 66   After the devastating events of Avengers: Infi...
# 655  A paraplegic Marine dispatched to the moon Pan...
# 67   The Avengers and their allies must be willing ...
# 680  A seventeen-year-old aristocrat falls in love ...
# 380  Earth's mightiest heroes must come together an...
# 922  The Incredibles family takes on a new mission ...
# 4    When the menace known as the Joker wreaks havo...
# 611  In a time of conflict, a group of unlikely her...
# 70   Eight years after the Joker's reign of anarchy...
# 712  A troubled child summons the courage to help a...
# 766  When a new toy called "Forky" joins Woody and ...
# 47   Lion prince Simba and his father are targeted ...
# 162  The toys are mistakenly delivered to a day-car...
# 612  Political involvement in the Avengers' affairs...
# 278  A pragmatic paleontologist touring an almost c...
# 920  The Guardians struggle to keep together as a t...
# 237  Harry, Ron, and Hermione search for Voldemort'...
# 256  After his son is captured in the Great Barrier...
# 7    Gandalf and Aragorn lead the World of Men agai...
#
#                                   director  \
# 618                            J.J. Abrams
# 66      Directors:Anthony Russo, Joe Russo
# 655                          James Cameron
# 67      Directors:Anthony Russo, Joe Russo
# 680                          James Cameron
# 380                            Joss Whedon
# 922                              Brad Bird
# 4                        Christopher Nolan
# 611                         Gareth Edwards
# 70                       Christopher Nolan
# 712                       Steven Spielberg
# 766                            Josh Cooley
# 47     Directors:Roger Allers, Rob Minkoff
# 162                            Lee Unkrich
# 612     Directors:Anthony Russo, Joe Russo
# 278                       Steven Spielberg
# 920                             James Gunn
# 237                            David Yates
# 256  Directors:Andrew Stanton, Lee Unkrich
# 7                            Peter Jackson
#
#                                                   star  \
# 618  'Daisy Ridley' 'John Boyega' 'Oscar Isaac' 'Do...
# 66   'Robert Downey Jr.' 'Chris Evans' 'Mark Ruffal...
# 655  'Sam Worthington' 'Zoe Saldana' 'Sigourney Wea...
# 67   'Robert Downey Jr.' 'Chris Hemsworth' 'Mark Ru...
# 680  'Leonardo DiCaprio' 'Kate Winslet' 'Billy Zane...
# 380  'Robert Downey Jr.' 'Chris Evans' 'Scarlett Jo...
# 922  'Craig T. Nelson' 'Holly Hunter' 'Sarah Vowell...
# 4    'Christian Bale' 'Heath Ledger' 'Aaron Eckhart...
# 611  'Felicity Jones' 'Diego Luna' 'Alan Tudyk' 'Do...
# 70   'Christian Bale' 'Tom Hardy' 'Anne Hathaway' '...
# 712  'Henry Thomas' 'Drew Barrymore' 'Peter Coyote'...
# 766  'Tom Hanks' 'Tim Allen' 'Annie Potts' 'Tony Hale'
# 47   'Matthew Broderick' 'Jeremy Irons' 'James Earl...
# 162  'Tom Hanks' 'Tim Allen' 'Joan Cusack' 'Ned Bea...
# 612  'Chris Evans' 'Robert Downey Jr.' 'Scarlett Jo...
# 278  'Sam Neill' 'Laura Dern' 'Jeff Goldblum' 'Rich...
# 920  'Chris Pratt' 'Zoe Saldana' 'Dave Bautista' 'V...
# 237  'Daniel Radcliffe' 'Emma Watson' 'Rupert Grint...
# 256  'Albert Brooks' 'Ellen DeGeneres' 'Alexander G...
# 7    'Elijah Wood' 'Viggo Mortensen' 'Ian McKellen'...
#
#                                         genre
# 618     Action, Adventure, Sci-Fi
# 66       Action, Adventure, Drama
# 655    Action, Adventure, Fantasy
# 67      Action, Adventure, Sci-Fi
# 680                Drama, Romance
# 380     Action, Adventure, Sci-Fi
# 922  Animation, Action, Adventure
# 4            Action, Crime, Drama
# 611     Action, Adventure, Sci-Fi
# 70           Action, Crime, Drama
# 712     Adventure, Family, Sci-Fi
# 766  Animation, Adventure, Comedy
# 47    Animation, Adventure, Drama
# 162  Animation, Adventure, Comedy
# 612     Action, Adventure, Sci-Fi
# 278     Action, Adventure, Sci-Fi
# 920     Action, Adventure, Comedy
# 237   Adventure, Fantasy, Mystery
# 256  Animation, Adventure, Comedy
# 7        Action, Adventure, Drama

# %%
top.to_csv("../data/top.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-95-61d422bf5f1f> in <module>
# ----> 1 top.to_csv("../data/top.csv")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: '../data/top.csv'

# %%
rating.head()

# %%
movies.head(30)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import rcParams
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
# %matplotlib inline

# %%
# Total
print (f"{len(movies)} movies in total.")

# %%
# Genres
all_genres = [s.split("|") for s in movies[movies.genres.notnull()].genres]
genres = [item for l in all_genres for item in l ]
unique_genres = set(genres)
print (f"total of {len(unique_genres)} unique genres from {len(genres)} occurances.")
pd.Series(genres).value_counts().plot(kind='bar', figsize=(10, 3))
plt.title("# of movies per genre")
plt.ylabel("# of movies")
plt.xlabel("genre")
plt.show()

# %%
# Genres
all_genres = [s.split(",") for s in top[top.genre.notnull()].genre]
genres = [item for l in all_genres for item in l ]
unique_genres = set(genres)
print (f"total of {len(unique_genres)} unique genres from {len(genres)} occurances.")
pd.Series(genres).value_counts().plot(kind='bar', figsize=(10, 3))
plt.title("# of movies per genre")
plt.ylabel("# of movies")
plt.xlabel("genre")
plt.show()

# %%
# Sort by popularity
sorted_by_popularity = top.sort_values(by='votes', ascending=False)
print ("Most popular movies:\n", sorted_by_popularity['movie'].values[:10])

# %%
# Sort by rating
sorted_by_popularity = top.sort_values(by='rating', ascending=False)
print ("Most Rated movies:\n", sorted_by_popularity['movie'].values[:10])

# %% [markdown]
# ## Ratings

# %%
# Distribution of ratings
print (rating['rating'].describe())
pd.Series(rating['rating']).value_counts().sort_index().plot(kind='bar', figsize=(5, 2))
plt.title("Distribution of ratings")
plt.ylabel("# of movies")
plt.xlabel("rating")
plt.show()

# %%
sorted_by_users = rating.groupby('userId')['movieId'].count().sort_values(ascending=False)
print ("Most active users:\n", sorted_by_users.values[:10])

# %%
sorted_by_movies = rating.groupby('movieId')['userId'].count().sort_values(ascending=False)
print ("Most rated movies:\n", sorted_by_movies.values[:10])

# %% [markdown]
# # Upcoming

# %%
up = pd.read_csv('../data/final_comingsoon.csv')

# %%
up.head()

# %%
up['Genre'] = up['Genre'].str.replace("<span>","")
up['Genre'] = up['Genre'].str.replace("</span>","")
#up.drop(['Unnamed: 0.1'], axis=1, inplace=True)
up['Genre'] = up['Genre'].str.replace("[","")
up['Genre'] = up['Genre'].str.replace("]","")
up['Genre'] = up['Genre'].str.replace("span","")
up['Genre'] = up['Genre'].str.replace("<","")
up['Genre'] = up['Genre'].str.replace(">","")
up['Genre'] = up['Genre'].str.replace("=","")
up['Genre'] = up['Genre'].str.replace("=","")

# %%
up.head()
