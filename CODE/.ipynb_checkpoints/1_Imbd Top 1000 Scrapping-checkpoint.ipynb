# %%
#importing the libraries needed 
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from time import sleep
from random import randint

#Declaring the headers 
headers = {"Accept-Language": "en-US,en;q=0.5"}

#declaring the list of empty variables, So that we can append the data overall

movie_name = []
year = []
time=[]
rating=[]
metascore =[]
votes = []
gross = []
description = []
Director = []
Stars = []
mgenre = []

#creating an array of values and passing it in the url for dynamic webpages
pages = np.arange(1,1000,100)

#the whole core of the script
for page in pages:
    page = requests.get("https://www.imdb.com/search/title/?groups=top_1000&sort=user_rating,desc&count=100&start="+str(page)+"&ref_=adv_nxt")
    soup = BeautifulSoup(page.text, 'html.parser')
    movie_data = soup.findAll('div', attrs = {'class': 'lister-item mode-advanced'})
    sleep(randint(2,8))
    for store in movie_data:
        name = store.h3.a.text
        movie_name.append(name)
        
        year_of_release = store.h3.find('span', class_ = "lister-item-year text-muted unbold").text
        year.append(year_of_release)
        
        runtime = store.p.find("span", class_ = 'runtime').text
        time.append(runtime)
        
        genre = store.p.find("span", class_ = 'genre').text
        mgenre.append(genre)
        
        rate = store.find('div', class_ = "inline-block ratings-imdb-rating").text.replace('\n', '')
        rating.append(rate)
        
        meta = store.find('span', class_ = "metascore").text if store.find('span', class_ = "metascore") else "****"
        metascore.append(meta)
        
        
        value = store.find_all('span', attrs = {'name': "nv"})
        
        vote = value[0].text
        votes.append(vote)
        
        grosses = value[1].text if len(value)>1 else '%^%^%^'
        gross.append(grosses)
        
        # Description of the Movies -- Not explained in the Video, But you will figure it out. 
        describe = store.find_all('p', class_ = 'text-muted')
        description_ = describe[1].text.replace('\n', '') if len(describe) >1 else '*****'
        description.append(description_)
        
        cast = store.find("p", class_ = '')
        cast = cast.text.replace('\n', '').split('|')
        cast = [x.strip() for x in cast]
        cast = [cast[i].replace(j, "") for i,j in enumerate(["Director:", "Stars:"])]
        Director.append(cast[0])
        Stars.append([x.strip() for x in cast[1].split(",")])
        
#creating a dataframe 
movie_list = pd.DataFrame({ "Movie Name": movie_name, "Year of Release" : year, "Watch Time": time,"Movie Rating": rating, "Meatscore of movie": metascore, "Votes" : votes, "Gross": gross, "Description": description, "Director": Director, 'Star': Stars,  "Genre": mgenre})

# %%
movie_list.head(10)
# Out:
#                                       Movie Name Year of Release Watch Time  \
# 0                                       Jai Bhim          (2021)    164 min
# 1                       The Shawshank Redemption          (1994)    142 min
# 2                                  The Godfather          (1972)    175 min
# 3                                Soorarai Pottru          (2020)    153 min
# 4                                The Dark Knight          (2008)    152 min
# 5                         The Godfather: Part II          (1974)    202 min
# 6                                   12 Angry Men          (1957)     96 min
# 7  The Lord of the Rings: The Return of the King          (2003)    201 min
# 8                                   Pulp Fiction          (1994)    154 min
# 9                               Schindler's List          (1993)    195 min
#
#   Movie Rating Meatscore of movie      Votes     Gross  \
# 0          9.4               ****    156,727    %^%^%^
# 1          9.3         80          2,504,396   $28.34M
# 2          9.2        100          1,726,289  $134.97M
# 3          9.1               ****    104,457    %^%^%^
# 4          9.0         84          2,453,910  $534.86M
# 5          9.0         90          1,197,868   $57.30M
# 6          9.0         96            739,690    $4.36M
# 7          8.9         94          1,730,076  $377.85M
# 8          8.9         94          1,932,435  $107.93M
# 9          8.9         94          1,281,487   $96.90M
#
#                                          Description              Director  \
# 0  When a tribal man is arrested for a case of al...         T.J. Gnanavel
# 1  Two imprisoned men bond over a number of years...        Frank Darabont
# 2  The Godfather follows Vito Corleone, Don of th...  Francis Ford Coppola
# 3  Nedumaaran Rajangam "Maara" sets out to make t...         Sudha Kongara
# 4  When the menace known as the Joker wreaks havo...     Christopher Nolan
# 5  The early life and career of Vito Corleone in ...  Francis Ford Coppola
# 6  The jury in a New York City murder trial is fr...          Sidney Lumet
# 7  Gandalf and Aragorn lead the World of Men agai...         Peter Jackson
# 8  The lives of two mob hitmen, a boxer, a gangst...     Quentin Tarantino
# 9  In German-occupied Poland during World War II,...      Steven Spielberg
#
#                                                 Star  \
# 0  [Suriya, Lijo Mol Jose, Manikandan, Rajisha Vi...
# 1  [Tim Robbins, Morgan Freeman, Bob Gunton, Will...
# 2  [Marlon Brando, Al Pacino, James Caan, Diane K...
# 3  [Suriya, Paresh Rawal, Aparna Balamurali, Gaur...
# 4  [Christian Bale, Heath Ledger, Aaron Eckhart, ...
# 5  [Al Pacino, Robert De Niro, Robert Duvall, Dia...
# 6  [Henry Fonda, Lee J. Cobb, Martin Balsam, John...
# 7  [Elijah Wood, Viggo Mortensen, Ian McKellen, O...
# 8  [John Travolta, Uma Thurman, Samuel L. Jackson...
# 9  [Liam Neeson, Ralph Fiennes, Ben Kingsley, Car...
#
#                                      Genre
# 0               \nCrime, Drama
# 1                      \nDrama
# 2               \nCrime, Drama
# 3                      \nDrama
# 4       \nAction, Crime, Drama
# 5               \nCrime, Drama
# 6               \nCrime, Drama
# 7   \nAction, Adventure, Drama
# 8               \nCrime, Drama
# 9  \nBiography, Drama, History

# %%
#Save to csv
movie_list.to_csv("../data/top.csv")
